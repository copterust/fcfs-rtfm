# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt
import re

def match_to_tuple(string):
    parts = string.split(',')
    return (int(parts[0]), int(parts[1]), int(parts[2]))

log = []
freq = None

with open('logc.txt', 'r', encoding='latin-1') as f:
    for line in f:
        parts = line.split(';')
        try:
            # ax,ay,az,gx,gy,gz,dt_s,y,p,r
            ax = parts[0]
            ay = parts[1]
            az = parts[2]
            gx = parts[3]
            gy = parts[4]
            gz = parts[5]
            dt = parts[6]
            y = parts[7]
            p = parts[8]
            r = parts[9]
            log.append((ax, ay, az, gx, gy, gz, y, p, r))
        except Exception as e:
            print('lol, err: {}'.format(e))

# %%
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 12, 12

yaws = list(map(lambda x: float(x[6]), log))
pitches = list(map(lambda x: float(x[7]), log))
rolls = list(map(lambda x: float(x[8]), log))

f, axarr = plt.subplots(3, sharex=True)

axarr[0].plot(np.degrees(yaws))
axarr[1].plot(np.degrees(pitches))
axarr[2].plot(np.degrees(rolls))
